# %% [markdown]
# <a href="https://colab.research.google.com/github/ahao1010/Predict_diamond_price/blob/main/ML_diamond.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
drive.mount('/content/drive')
df= pd.read_csv('/content/drive/MyDrive/diamonds.csv',index_col='Unnamed: 0')
df.info()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53940 entries, 1 to 53940
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.5+ MB

# %%
new_col_order = ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y','z','price']
df = df.reindex(columns=new_col_order)
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 1       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 2       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 3       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 4       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 5       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53937   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53938   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53939   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53940   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df=df.drop_duplicates()

# %%
df.describe()
# Out:
#              carat         depth         table             x             y  \
# count  53794.00000  53794.000000  53794.000000  53794.000000  53794.000000
# mean       0.79778     61.748080     57.458109      5.731214      5.734653
# std        0.47339      1.429909      2.233679      1.120695      1.141209
# min        0.20000     43.000000     43.000000      0.000000      0.000000
# 25%        0.40000     61.000000     56.000000      4.710000      4.720000
# 50%        0.70000     61.800000     57.000000      5.700000      5.710000
# 75%        1.04000     62.500000     59.000000      6.540000      6.540000
# max        5.01000     79.000000     95.000000     10.740000     58.900000
#
#                   z         price
# count  53794.000000  53794.000000
# mean       3.538714   3933.065082
# std        0.705037   3988.114460
# min        0.000000    326.000000
# 25%        2.910000    951.000000
# 50%        3.530000   2401.000000
# 75%        4.030000   5326.750000
# max       31.800000  18823.000000

# %%
df= df.drop(df[df['x']==0].index)
df= df.drop(df[df['y']==0].index)
df= df.drop(df[df['z']==0].index)

# %% [markdown]
# 1. Data Preprocessing

# %%
a=list(df.columns)
for i in a:
  print(df[i].value_counts())
  print('------------------------------')
# Out:
# 0.30    2596
# 0.31    2238
# 1.01    2238
# 0.70    1981
# 0.32    1827
#         ...
# 3.02       1
# 3.65       1
# 3.50       1
# 3.22       1
# 3.11       1
# Name: carat, Length: 273, dtype: int64
# ------------------------------
# Ideal        21485
# Premium      13737
# Very Good    12068
# Good          4888
# Fair          1597
# Name: cut, dtype: int64
# ------------------------------
# G    11254
# E     9776
# F     9517
# H     8266
# D     6754
# I     5406
# J     2802
# Name: color, dtype: int64
# ------------------------------
# SI1     13030
# VS2     12225
# SI2      9142
# VS1      8155
# VVS2     5056
# VVS1     3646
# IF       1784
# I1        737
# Name: clarity, dtype: int64
# ------------------------------
# 62.0    2233
# 61.9    2160
# 61.8    2069
# 62.2    2032
# 62.1    2010
#         ...
# 71.3       1
# 44.0       1
# 53.0       1
# 53.1       1
# 54.7       1
# Name: depth, Length: 184, dtype: int64
# ------------------------------
# 56.0    9849
# 57.0    9695
# 58.0    8349
# 59.0    6555
# 55.0    6242
#         ...
# 51.6       1
# 63.5       1
# 43.0       1
# 62.4       1
# 61.6       1
# Name: table, Length: 127, dtype: int64
# ------------------------------
# 4.37     444
# 4.34     436
# 4.33     428
# 4.38     426
# 4.32     422
#         ...
# 10.74      1
# 9.36       1
# 9.06       1
# 8.89       1
# 9.05       1
# Name: x, Length: 553, dtype: int64
# ------------------------------
# 4.34     436
# 4.37     432
# 4.35     424
# 4.33     420
# 4.32     411
#         ...
# 8.89       1
# 10.16      1
# 9.46       1
# 9.63       1
# 31.80      1
# Name: y, Length: 550, dtype: int64
# ------------------------------
# 2.70     761
# 2.69     745
# 2.71     733
# 2.68     730
# 2.72     691
#         ...
# 5.86       1
# 5.66       1
# 5.72       1
# 5.73       1
# 31.80      1
# Name: z, Length: 374, dtype: int64
# ------------------------------
# 605      132
# 802      126
# 625      125
# 828      124
# 776      124
#         ...
# 13211      1
# 13207      1
# 13205      1
# 13201      1
# 14717      1
# Name: price, Length: 11597, dtype: int64
# ------------------------------

# %%
Le = LabelEncoder()
df['cut'] = Le.fit_transform(df['cut'])
cut_mappings = {index: label for index, label in enumerate(Le.classes_)}
df['color'] = Le.fit_transform(df['color'])
color_mappings = {index: label for index, label in enumerate(Le.classes_)}
df['clarity'] = Le.fit_transform(df['clarity'])
clarity_mappings = {index: label for index, label in enumerate(Le.classes_)}
print(cut_mappings)
print(color_mappings)
print(clarity_mappings)
# Out:
# {0: 'Fair', 1: 'Good', 2: 'Ideal', 3: 'Premium', 4: 'Very Good'}
# {0: 'D', 1: 'E', 2: 'F', 3: 'G', 4: 'H', 5: 'I', 6: 'J'}
# {0: 'I1', 1: 'IF', 2: 'SI1', 3: 'SI2', 4: 'VS1', 5: 'VS2', 6: 'VVS1', 7: 'VVS2'}

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 1       0.23    2      1        3   61.5   55.0  3.95  3.98  2.43    326
# 2       0.21    3      1        2   59.8   61.0  3.89  3.84  2.31    326
# 3       0.23    1      1        4   56.9   65.0  4.05  4.07  2.31    327
# 4       0.29    3      5        5   62.4   58.0  4.20  4.23  2.63    334
# 5       0.31    1      6        3   63.3   58.0  4.34  4.35  2.75    335
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 53936   0.72    2      0        2   60.8   57.0  5.75  5.76  3.50   2757
# 53937   0.72    1      0        2   63.1   55.0  5.69  5.75  3.61   2757
# 53938   0.70    4      0        2   62.8   60.0  5.66  5.68  3.56   2757
# 53939   0.86    3      4        3   61.0   58.0  6.15  6.12  3.74   2757
# 53940   0.75    2      0        3   62.2   55.0  5.83  5.87  3.64   2757
#
# [53775 rows x 10 columns]

# %%
columns= list(df.columns)
fig= sns.boxplot(data=df)
fig.set_xticks(range(len(columns)))
fig.set_xticklabels(columns)
# Out:
# [Text(0, 0, 'carat'),
#  Text(1, 0, 'cut'),
#  Text(2, 0, 'color'),
#  Text(3, 0, 'clarity'),
#  Text(4, 0, 'depth'),
#  Text(5, 0, 'table'),
#  Text(6, 0, 'x'),
#  Text(7, 0, 'y'),
#  Text(8, 0, 'z'),
#  Text(9, 0, 'price')]

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
# Tính IQR
iqr = q3 - q1
iqr
df_without_outlier = df[-((df < (q1 - 1.5 * iqr)) |(df > (q3 + 1.5* iqr))).any(axis=1)]
df_without_outlier
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 1       0.23    2      1        3   61.5   55.0  3.95  3.98  2.43    326
# 2       0.21    3      1        2   59.8   61.0  3.89  3.84  2.31    326
# 4       0.29    3      5        5   62.4   58.0  4.20  4.23  2.63    334
# 5       0.31    1      6        3   63.3   58.0  4.34  4.35  2.75    335
# 6       0.24    4      6        7   62.8   57.0  3.94  3.96  2.48    336
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 53936   0.72    2      0        2   60.8   57.0  5.75  5.76  3.50   2757
# 53937   0.72    1      0        2   63.1   55.0  5.69  5.75  3.61   2757
# 53938   0.70    4      0        2   62.8   60.0  5.66  5.68  3.56   2757
# 53939   0.86    3      4        3   61.0   58.0  6.15  6.12  3.74   2757
# 53940   0.75    2      0        3   62.2   55.0  5.83  5.87  3.64   2757
#
# [47082 rows x 10 columns]

# %%
fig= sns.boxplot(data=df_without_outlier)
fig.set_xticks(range(len(columns)))
fig.set_xticklabels(columns)
# Out:
# [Text(0, 0, 'carat'),
#  Text(1, 0, 'cut'),
#  Text(2, 0, 'color'),
#  Text(3, 0, 'clarity'),
#  Text(4, 0, 'depth'),
#  Text(5, 0, 'table'),
#  Text(6, 0, 'x'),
#  Text(7, 0, 'y'),
#  Text(8, 0, 'z'),
#  Text(9, 0, 'price')]

# %%
corr_matrix = df_without_outlier.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
X=df_without_outlier.drop(['price','clarity','cut','depth'],axis=1)
y= df_without_outlier['price']
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3, random_state=101)

# %%
print(f"x_train shape: {X_train.shape}\nx_test shape: {X_test.shape}\ny_train shape: {y_train.shape}\ny_test shape: {y_test.shape}")
# Out:
# x_train shape: (32957, 6)
# x_test shape: (14125, 6)
# y_train shape: (32957,)
# y_test shape: (14125,)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# 2. Training Model

# %% [markdown]
# 2.1 Decision Tree

# %%
model= DecisionTreeRegressor()
model.fit(X_train,y_train)
y_pred_id3= model.predict(X_test)

# %% [markdown]
# 2.2 SVM

# %%
model= RandomForestRegressor()
model.fit(X_train,y_train)
y_pred_rd= model.predict(X_test)

# %% [markdown]
#  2.3. Logistc Regression

# %%
model= SVR(kernel='linear')
model.fit(X_train,y_train)
y_pred_svr= model.predict(X_test)

# %% [markdown]
# 2.4 KNN

# %%
model= KNeighborsRegressor()
model.fit(X_train,y_train)
y_pred_knn= model.predict(X_test)

# %% [markdown]
# 2.5 Linear Regression

# %%
model= LinearRegression()
model.fit(X_train,y_train)
y_pred_ln= model.predict(X_test)

# %% [markdown]
# 3. Đánh giá mô hình

# %%
from sklearn.metrics import mean_absolute_percentage_error
listForModels = ["Decision Tree", "Kneighbor Regression", "Support Vector Regression",  "Random Forest","Linear Regression"]
listForPredictions = [y_pred_id3,y_pred_knn,y_pred_svr,y_pred_rd,y_pred_ln]
def comparisonModels(listForModels,listForPredictions,y_test):
    for modelName, predictions in zip(listForModels, listForPredictions):
        mae = round(mean_absolute_error(y_test,predictions), 1)
        r2 = round(r2_score(y_test,predictions), 2)
        mape = round(mean_absolute_percentage_error(y_test,predictions)*100, 1)
        print(f"Model Name: {modelName}")
        print(f"Mean Absoulute Error: {mae}")
        print(f"R-Score: {r2}")
        print(f"Mean Absoulute Percentage Error: {mape}%")
        print("\n")
comparisonModels(listForModels,listForPredictions,y_test)
# Out:
# Model Name: Decision Tree
# Mean Absoulute Error: 653.8
# R-Score: 0.82
# Mean Absoulute Percentage Error: 21.5%
#
#
# Model Name: Kneighbor Regression
# Mean Absoulute Error: 525.0
# R-Score: 0.89
# Mean Absoulute Percentage Error: 17.4%
#
#
# Model Name: Support Vector Regression
# Mean Absoulute Error: 656.7
# R-Score: 0.83
# Mean Absoulute Percentage Error: 23.8%
#
#
# Model Name: Random Forest
# Mean Absoulute Error: 500.7
# R-Score: 0.9
# Mean Absoulute Percentage Error: 16.5%
#
#
# Model Name: Linear Regression
# Mean Absoulute Error: 624.2
# R-Score: 0.87
# Mean Absoulute Percentage Error: 26.8%
